# %% [markdown]
# # Implementation of a Newton–Raphson solver for nonlinear elasticity

# %% [markdown]
# In this notebook, we will analyse the same problem as in the previous notebook [Hyperelasticity_problem.ipynb](Hyperelasticity_problem.ipynb). However, this time, we will implement or own Newton–Raphson solver, rather than rely on FEniCS's `NonlinearVariationalSolver`.
#
# You need to fill in the blank lines that are indicated as follows
# ```
# # COMPLETE THIS LINE
# ```
#
# Until you do that, the Notebook will *not* work properly.

# %% [markdown]
# ## Setting up the problem

# %% [markdown]
# The code below is merely a copy/paste of the code from the previous sessions, as we use the same problem to illustrate the implementation of the Newton–Raphson iterations.

# %% [markdown]
# #### Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import math as m

import dolfin
import ufl
import os.path

# %matplotlib inline

dolfin.parameters["form_compiler"]["cpp_optimize"] = True
dolfin.parameters["form_compiler"]["representation"] = "uflacs"
plt.style.use("seaborn-notebook")

# %% [markdown]
# ### Parameters of the simulation

# %% [markdown]
# Place here the parameters that can be changed without altering the logics of the code.

# %%
# Physical mesh : rectangle 2D beam

Lx = 1.0
Ly = Lx / 10     # Dimensions of the beam

nx = 20          # Number of elements in each direction
ny = int(nx / 5) # Number of elements in each direction

Y, nu  =  1e3, 0.3  # Young modulus and Poisson ratio
g  = 1.
alpha = 1.

load_min, load_max, n_loads = 0.0, 0.3, 35 # Loading schedule
degree = 2 # degree basis function

output_dir = "nr_output"
print(6*Lx**3/((1+nu)*Ly**2) ) # Gamma / t # What is it ???
# Out:
# 461.53846153846143

# %% [markdown]
# You should not alter the cell below

# %%
loads = np.linspace(load_min, load_max, n_loads)

mu    = dolfin.Constant(Y/(2*(1 + nu)))
lmbda = dolfin.Constant(Y*nu/((1 + nu)*(1 - 2*nu)))
lmbda = 2*lmbda*mu/(lmbda + 2*mu)

# %% [markdown]
# ### Numerical mesh

# %%
mesh  = dolfin.RectangleMesh(dolfin.Point(0,0),
                             dolfin.Point(Lx,Ly),
                             nx, ny)

left  = dolfin.CompiledSubDomain("near(x[0],0) && on_boundary")
right = dolfin.CompiledSubDomain("near(x[0],Lx) && on_boundary", Lx=Lx)

boundary_markers = dolfin.MeshFunction("size_t", 
                                       mesh, 
                                       1, #dim
                                       0) #value

boundary_indices = {"left": 1, "right": 2}
left.mark (boundary_markers, boundary_indices["left"] )
right.mark(boundary_markers, boundary_indices["right"])

ds = dolfin.ds(domain=mesh,subdomain_data=boundary_markers)
dx = dolfin.dx(domain=mesh)

# %% [markdown]
# ### Function space

# %%
V_element = dolfin.VectorElement("CG", #usual Lagrangian elements
                                 mesh.ufl_cell(), 
                                 degree=degree) #2

V = dolfin.FunctionSpace(mesh, V_element)
u = dolfin.Function(V, name="u") #name allows to work as with a pointer

# %% [markdown]
# ### Potential energy

# %% [markdown]
# We first define the strain energy of a (compressible) neo-Hookean material.

# %%
# Data tensors

def tensors(u):

    """ Function returning a bunch of 
    tensors and other variables."""
    
    I   = ufl.Identity(2)             #2x2 identity matrix
    F   = ufl.variable(I+ufl.grad(u)) #Tensor transformation ref to cur 
    C   = F.T*F                       #Cauchy tensor                   
    Ic  = ufl.tr(C)
    J   = ufl.det(F)                  #Jacobian transformation ref to cur
    E   = 1/2*(C-I)                   #Non-linear strain tensor

    return I, F, C, Ic, J, E

I, F, C, Ic, J, E = tensors(u)

#Hookean potential energy
psi = (mu/2)*(Ic-2)-mu*ufl.ln(J)+(lmbda/2)*(ufl.ln(J))**2

# %% [markdown]
# We then define the loading (body forces $\mathbf{B}$).

# %% [markdown]
# # Change code to allow one to specify forces vectors as an entry

# %%
# B = dolfin.Expression(("0.0", "-mu*t *(cos(alpha), sin(alpha))"), t=0, alpha=alpha, mu=mu, degree=0)
B = dolfin.Expression(("-mu*t*cos(alpha)", "mu*t*sin(alpha)"), t=0, alpha=alpha, mu=mu, degree=2)
T = dolfin.Constant((0.0, 0.0))

# %% [markdown]
# We can now define the potential energy and its derivatives w.r.t the displacement $\mathbf{u}$.

# %%
# WF
potential_energy = psi*dx - ufl.dot(B, u)*dx - ufl.dot(T, u)*ds(boundary_indices['right'])

residual = ufl.derivative(potential_energy, u, dolfin.TestFunction (V))
jacobian = ufl.derivative(residual        , u, dolfin.TrialFunction(V))

# %% [markdown]
# Boundary conditions for a built-in support on the left-hand side.

# %%
bcs = [dolfin.DirichletBC(V, (0.,0.), left)] #embedded condition to the left (x[0]==0)

# %% [markdown]
# ### Computing the reference solution

# %% [markdown]
# We use the built-in non-linear solver to compute a reference solution, which we will compare to the solution computed with our own NR solver.

# %%
# Function building F(u, v)=0 with F = residual here
problem   = dolfin.NonlinearVariationalProblem(residual, u, bcs=bcs, J=jacobian)
solver    = dolfin.NonlinearVariationalSolver(problem)

displ_ref = np.zeros_like(loads)
u.interpolate(dolfin.Constant((0., 0.)))

file_u = dolfin.XDMFFile(os.path.join(output_dir, "u_ref.xdmf"))
file_u.parameters.update({"flush_output":True,
                          "functions_share_mesh":True,
                          "rewrite_function_mesh":False})

for (i, t) in enumerate(loads):
    B.t = t       #add load to downwards gravity force
    solver.solve()
    
    displ_ref[i] = dolfin.assemble(u[1]*ds(boundary_indices["right"]))/Ly 
    #print("t={:+3.3f}, u={:+3.3f}".format(t,displ_ref[i]))
    with file_u as file:
        file.write(u,t)
        
plt.plot(loads, displ_ref, "o")

plt.title(r'mean $v(x=L)$ in function of loading')
plt.xlabel('load')
plt.ylabel(r'$v(x=L)$')

plt.grid(True)

# %% [markdown]
# ## Implementation of the Newton–Raphson solver

# %% [markdown]
# We will discuss the statement below in class.

# %%
bcs_homo = bcs

# %%
def simple_monitor(iteration, u, norm_u, norm_delta_u, norm_residual):
    
    """ Function displaying information on solution (residual, error, ...). """
    
    print("Iteration: {:3d}, Error: {:3.4e}, Residual: {:3.4e}".format(iteration, norm_delta_u, norm_residual))

# -----------

def plot_monitor(iteration, u, norm_u, norm_delta_u, norm_residual):
    
    """ Function ploting u displacement. """
    
    simple_monitor(iteration, u, norm_u, norm_delta_u, norm_residual)
    
    plt.figure()
    dolfin.plot(u, mode="displacement") 

# -----------

def newton_solver(u, max_iter=100, rtol=1e-6, atol=1e-6, monitor=None):
    
    """ Newton Raphson solver returing converging u value 
    given u (initial guess ??) and nb iterations. """

    delta_u = dolfin.Function(V)
    delta_u.interpolate(dolfin.Constant((0., 0.)))

    bcs_homo = bcs

    for k in range(max_iter):

        # Solve the linearized problem for the increment delta_u with homogenous BCs
        problem_lin = dolfin.LinearVariationalProblem(jacobian, -residual, delta_u, bcs_homo)
        solver_lin  = dolfin.LinearVariationalSolver(problem_lin)
        solver_lin.solve() #value delta_u automatically updated
        
        # Update the solution
        u.assign(u+delta_u) #keeps u and du as 2 separate variables

        # ------------------
        # error calculation
        # ------------------

        # Stopping criterion based on the L2 norm of u and delta_u
        norm_delta_u = dolfin.norm(delta_u, "L2")
        norm_u       = dolfin.norm(      u, "L2")
            
        intR = dolfin.assemble(residual)
        bc.apply(intR)
        norm_residual = dolfin.norm(intR, "L2")
        
        # -----------------
        
        if monitor is not None:
            monitor(k, u, norm_u, norm_delta_u, norm_residual)
        
        else:
            # See for-else statement:
            # https://book.pythontips.com/en/latest/for_-_else.html#else-clause
            # This block is entered only if the above loop completes,
            # which means that the maximum number of iterations has been reached.
            1==1
#             print('You decided to display nothing')
#             raise RuntimeError("could not converge, norm_u {}, norm_delta_u {}".format(norm_u, norm_delta_u)) 

    return k

# %% [markdown]
# We are now ready to call our solver, first with a very small load, so that the solution is nearly that of the linear problem, and the algorithm should converge in one iteration.

# %%
bc = dolfin.DirichletBC(V, (0.,0.), left) #embedded condition to the left (x[0]==0)

# u = dolfin.Function(V)
u.interpolate(dolfin.Constant((0.0, 0.0)))
B.t = 1E-4

newton_solver(u, max_iter=3, monitor=simple_monitor)
# Out:
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Calling FFC just-in-time (JIT) compiler, this may take some time.
# Iteration:   0, Error: 7.8681e-04, Residual: 5.2765e-03
# Iteration:   1, Error: 3.1267e-06, Residual: 1.1172e-07
# Iteration:   2, Error: 5.4973e-08, Residual: 3.6111e-11
# 2

# %% [markdown]
# Let's try a slightly higher load. We will plot the estimate of the solution at each iteration. It is interesting to observe the iterates converge to the solution.

# %%
u.interpolate(dolfin.Constant((0., 0.)))
B.t = 1.5*load_max/n_loads

newton_solver(u, max_iter=10, monitor=plot_monitor)
# Out:
# Iteration:   0, Error: 1.0116e-01, Residual: 6.1878e+01
# Iteration:   1, Error: 3.5534e-02, Residual: 1.8847e+01
# Iteration:   2, Error: 5.5113e-03, Residual: 1.1857e+00
# Iteration:   3, Error: 2.0992e-03, Residual: 7.2669e-01
# Iteration:   4, Error: 8.2771e-03, Residual: 9.7412e-01
# Iteration:   5, Error: 3.2193e-03, Residual: 2.5033e-01
# Iteration:   6, Error: 8.9422e-03, Residual: 1.0636e+00
# Iteration:   7, Error: 1.3326e-03, Residual: 3.3741e-02
# Iteration:   8, Error: 6.2991e-03, Residual: 5.4377e-01
# Iteration:   9, Error: 2.2990e-04, Residual: 1.3837e-03
# 9

# %% [markdown]
# ### Illustrating quadratic convergence

# %% [markdown]
# We now want to verify that the Newton–Raphson iterations converge quadratically, that is $\epsilon_{n+1} \leq C\epsilon_n^2$, where $\epsilon_n$ denotes the error of the $n$-th iterate. Since we do not know the exact solution of the problem, we will take the last iterate as a reference.
#
# We implement a new `monitor` that keeps a copy of each iterate.

# %%
iterates = []

def my_monitor(iteration, u, u_norm, delta_u_norm, residual_norm):
    simple_monitor(iteration, u, u_norm, delta_u_norm, residual_norm)
    iterates.append(u.copy(deepcopy=True))

u.interpolate(dolfin.Constant((0., 0.)))
B.t = 1.5*load_max/n_loads
newton_solver(u, monitor=my_monitor, rtol=1e-10, atol=1e-10)
# Out:
# Iteration:   0, Error: 1.0116e-01, Residual: 6.1878e+01
# Iteration:   1, Error: 3.5534e-02, Residual: 1.8847e+01
# Iteration:   2, Error: 5.5113e-03, Residual: 1.1857e+00
# Iteration:   3, Error: 2.0992e-03, Residual: 7.2669e-01
# Iteration:   4, Error: 8.2771e-03, Residual: 9.7412e-01
# Iteration:   5, Error: 3.2193e-03, Residual: 2.5033e-01
# Iteration:   6, Error: 8.9422e-03, Residual: 1.0636e+00
# Iteration:   7, Error: 1.3326e-03, Residual: 3.3741e-02
# Iteration:   8, Error: 6.2991e-03, Residual: 5.4377e-01
# Iteration:   9, Error: 2.2990e-04, Residual: 1.3837e-03
# Iteration:  10, Error: 4.6220e-04, Residual: 2.9758e-03
# Iteration:  11, Error: 1.9053e-06, Residual: 5.3871e-08
# Iteration:  12, Error: 2.0985e-08, Residual: 6.2181e-12
# Iteration:  13, Error: 2.2999e-15, Residual: 1.6625e-12
# Iteration:  14, Error: 5.3176e-17, Residual: 1.5679e-12
# Iteration:  15, Error: 1.6599e-16, Residual: 1.9482e-12
# Iteration:  16, Error: 1.0008e-16, Residual: 1.9691e-12
# Iteration:  17, Error: 1.9256e-17, Residual: 1.4431e-12
# Iteration:  18, Error: 1.8988e-16, Residual: 1.8001e-12
# Iteration:  19, Error: 5.3179e-17, Residual: 1.8741e-12
# Iteration:  20, Error: 3.7609e-17, Residual: 1.6259e-12
# Iteration:  21, Error: 7.5792e-17, Residual: 1.6665e-12
# Iteration:  22, Error: 1.5073e-16, Residual: 1.5944e-12
# Iteration:  23, Error: 1.8819e-16, Residual: 1.7042e-12
# Iteration:  24, Error: 1.8379e-16, Residual: 1.6006e-12
# Iteration:  25, Error: 1.2800e-16, Residual: 1.4918e-12
# Iteration:  26, Error: 2.2712e-16, Residual: 1.7098e-12
# Iteration:  27, Error: 1.3530e-16, Residual: 1.7951e-12
# Iteration:  28, Error: 4.8104e-17, Residual: 1.8530e-12
# Iteration:  29, Error: 2.3106e-17, Residual: 1.5925e-12
# Iteration:  30, Error: 7.4796e-17, Residual: 1.8929e-12
# Iteration:  31, Error: 1.1736e-16, Residual: 1.7377e-12
# Iteration:  32, Error: 7.4494e-17, Residual: 1.7245e-12
# Iteration:  33, Error: 4.6426e-16, Residual: 1.6847e-12
# Iteration:  34, Error: 4.1583e-16, Residual: 1.6327e-12
# Iteration:  35, Error: 2.0906e-16, Residual: 1.7471e-12
# Iteration:  36, Error: 9.6573e-17, Residual: 1.7083e-12
# Iteration:  37, Error: 3.3740e-16, Residual: 1.8441e-12
# Iteration:  38, Error: 3.2742e-16, Residual: 1.7971e-12
# Iteration:  39, Error: 1.2771e-16, Residual: 1.6309e-12
# Iteration:  40, Error: 1.4027e-16, Residual: 1.5892e-12
# Iteration:  41, Error: 5.4337e-17, Residual: 1.5893e-12
# Iteration:  42, Error: 1.2993e-17, Residual: 1.6344e-12
# Iteration:  43, Error: 2.2525e-16, Residual: 1.5415e-12
# Iteration:  44, Error: 9.2037e-17, Residual: 1.8108e-12
# Iteration:  45, Error: 7.2991e-17, Residual: 1.7141e-12
# Iteration:  46, Error: 3.4110e-17, Residual: 1.5920e-12
# Iteration:  47, Error: 9.3395e-17, Residual: 1.7904e-12
# Iteration:  48, Error: 3.2044e-16, Residual: 1.7756e-12
# Iteration:  49, Error: 2.0902e-16, Residual: 1.7677e-12
# Iteration:  50, Error: 1.2895e-16, Residual: 1.9415e-12
# Iteration:  51, Error: 3.6366e-17, Residual: 1.5354e-12
# Iteration:  52, Error: 5.2139e-17, Residual: 1.5788e-12
# Iteration:  53, Error: 1.8216e-17, Residual: 1.9596e-12
# Iteration:  54, Error: 3.0313e-17, Residual: 1.7562e-12
# Iteration:  55, Error: 9.1810e-17, Residual: 1.7228e-12
# Iteration:  56, Error: 3.3458e-17, Residual: 1.7624e-12
# Iteration:  57, Error: 2.4844e-16, Residual: 1.4762e-12
# Iteration:  58, Error: 2.3056e-16, Residual: 1.6777e-12
# Iteration:  59, Error: 2.7484e-16, Residual: 1.5707e-12
# Iteration:  60, Error: 1.0920e-16, Residual: 1.7680e-12
# Iteration:  61, Error: 7.3463e-17, Residual: 1.7493e-12
# Iteration:  62, Error: 1.8262e-16, Residual: 1.6123e-12
# Iteration:  63, Error: 2.3240e-16, Residual: 1.8152e-12
# Iteration:  64, Error: 1.2682e-16, Residual: 1.5926e-12
# Iteration:  65, Error: 5.1722e-17, Residual: 1.7426e-12
# Iteration:  66, Error: 4.5285e-17, Residual: 1.6943e-12
# Iteration:  67, Error: 1.3053e-16, Residual: 1.6595e-12
# Iteration:  68, Error: 9.1451e-17, Residual: 1.6929e-12
# Iteration:  69, Error: 1.7487e-16, Residual: 1.7109e-12
# Iteration:  70, Error: 1.5888e-16, Residual: 1.7308e-12
# Iteration:  71, Error: 1.2691e-17, Residual: 1.6771e-12
# Iteration:  72, Error: 3.0227e-17, Residual: 1.8291e-12
# Iteration:  73, Error: 9.8253e-17, Residual: 1.7088e-12
# Iteration:  74, Error: 1.0792e-16, Residual: 1.6003e-12
# Iteration:  75, Error: 7.7469e-17, Residual: 1.7406e-12
# Iteration:  76, Error: 6.8922e-17, Residual: 1.6212e-12
# Iteration:  77, Error: 1.7806e-16, Residual: 1.5413e-12
# Iteration:  78, Error: 2.3184e-16, Residual: 1.6429e-12
# Iteration:  79, Error: 1.5445e-16, Residual: 1.7205e-12
# Iteration:  80, Error: 3.4805e-16, Residual: 1.7540e-12
# Iteration:  81, Error: 2.4998e-16, Residual: 1.6300e-12
# Iteration:  82, Error: 1.0795e-16, Residual: 1.6508e-12
# Iteration:  83, Error: 1.1807e-16, Residual: 1.9160e-12
# Iteration:  84, Error: 5.4964e-17, Residual: 1.8937e-12
# Iteration:  85, Error: 1.7713e-17, Residual: 1.5224e-12
# Iteration:  86, Error: 3.0987e-17, Residual: 1.8600e-12
# Iteration:  87, Error: 1.5675e-16, Residual: 1.7956e-12
# Iteration:  88, Error: 1.4439e-16, Residual: 1.5937e-12
# Iteration:  89, Error: 8.2870e-17, Residual: 1.7727e-12
# Iteration:  90, Error: 1.9073e-17, Residual: 1.6932e-12
# Iteration:  91, Error: 5.2383e-17, Residual: 1.6229e-12
# Iteration:  92, Error: 1.3217e-16, Residual: 1.6452e-12
# Iteration:  93, Error: 3.5676e-17, Residual: 1.6813e-12
# Iteration:  94, Error: 3.5854e-17, Residual: 1.7113e-12
# Iteration:  95, Error: 2.5681e-17, Residual: 1.7136e-12
# Iteration:  96, Error: 5.3890e-17, Residual: 1.7636e-12
# Iteration:  97, Error: 3.0031e-17, Residual: 1.6657e-12
# Iteration:  98, Error: 4.1520e-17, Residual: 1.6727e-12
# Iteration:  99, Error: 6.0134e-17, Residual: 1.7084e-12
# 99

# %% [markdown]
# **When approaching the solution, we should have** $r^{n+1} = r^{2n}$

# %%
L2_errors = np.zeros(len(iterates), dtype=np.float64)
H1_errors = np.zeros_like(L2_errors)
u_ref = iterates[-1]

for i, u_i in enumerate(iterates):
    L2_errors[i] = dolfin.errornorm(u_ref, u_i, 'L2')
    H1_errors[i] = dolfin.errornorm(u_ref, u_i, 'H1')

# %%
plt.xlabel(r'$\epsilon_n^2$')
plt.ylabel(r'$\epsilon_{n+1}$')

plt.loglog(L2_errors[:-2], L2_errors[1:-1], 'o-')
plt.loglog(L2_errors[:-2], L2_errors[:-2]**1.5)

# %%
plt.xlabel(r'$\epsilon_n^2$')
plt.ylabel(r'$\epsilon_{n+1}$')

plt.loglog(H1_errors[:-2], H1_errors[1:-1], 'o-')
plt.loglog(H1_errors[:-2], H1_errors[:-2]**1.5)

# %% [markdown]
# Bulk force depends a lot on degree at sin and cos are tricky :
#
# * cos is of order 1 if degree 0
# * cos is of order 1 if degree 1
# * cos is of order 2 if degree 2
#
# and similarly :
#
# * sin is of order 0 if degree 0
# * sin is of order 2 if degree 1
# * sin is of order 2 if degree 2
#
# Then, we must adapt degree to fit expectation of order 2 (ddue to order 2 modellization, elements, etc).
#
# Oscillations when converging may be due to the value of cos and sin is very value dependant, i.e. non-so-smooth values + sign variations.

# %% [markdown]
# ## Validation of the solver

# %% [markdown]
# We now run the whole simulation and compare with the reference solution.

# %%
file_u = dolfin.XDMFFile(os.path.join(output_dir, "u.xdmf"))
file_u.parameters.update({"flush_output":True,
                          "functions_share_mesh":True,
                          "rewrite_function_mesh":False})

# initialisation
displ = np.zeros_like(loads)
u.interpolate(dolfin.Constant((0.,0.)))

B.t     = .5
B.alpha = 0

for (i, alpha) in enumerate(loads):
    B.alpha = alpha
    newton_solver(u, max_iter=10, monitor=None)
    displ[i] = dolfin.assemble(u[1]*ds(2))/Ly 
    #print("t={:+3.3f}, u={:+3.3f}".format(t,displ_ref[i]))
    with file_u as file:
        file.write(u,t)

# plt.plot(loads, displ_ref, "-", label='Reference implementation')
plt.plot(loads, displ, 'o', label='Our implementation')

plt.title(r'$u_y[L]$ as a function of loading coeff $\alpha$ at t={}s'.format(B.t))
plt.ylabel(r"$u_y[L]$")
plt.xlabel(r"loading coeff $\alpha$")

plt.grid(True)
plt.legend()

# %% [markdown]
# $\Rightarrow$ For a sinusoidal distributed load, we have :
# * an order of convergence that is not quiet quadratic
# * non linearities appearing for a too high loading

# %% [markdown]
# Note that for alpha max = 0.3 rad, we are at an angle below 20°, which is in linear framework. The, the non-linearities are due to a too high loading resulting in big displacement.
